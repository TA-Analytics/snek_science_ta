# %%
# get libs and resources
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import re
import pandas as pd

# %%
# specify page
page = 'https://lifehacker.com/'

# %%
# build request
req = Request(page)
html_page = urlopen(req)
soup = BeautifulSoup(html_page, "lxml")

# %%
# create space for links, and loop through specified elements
links = []
for link in soup.findAll('a'):
    links.append(link.get('href'))

# %%
# create dataframe
df = pd.DataFrame(links)

# %%
links
# Out:
# [None,
#  '//avclub.com',
#  '//deadspin.com',
#  '//gizmodo.com',
#  '//jalopnik.com',
#  '//jezebel.com',
#  '//kotaku.com',
#  '//lifehacker.com',
#  '//splinternews.com',
#  '//thetakeout.com',
#  '//theroot.com',
#  '//theonion.com',
#  '//clickhole.com',
#  '//theinventory.com',
#  '//lifehacker.com',
#  '//lifehacker.com/video',
#  '//skillet.lifehacker.com',
#  '//twocents.lifehacker.com',
#  '//vitals.lifehacker.com',
#  '//offspring.lifehacker.com',
#  '//lifehacker.com/c/the-upgrade',
#  '//lifehacker.com/c/app-directory',
#  '//lifehacker.com/c/how-i-work',
#  None,
#  '//lifehacker.com/video',
#  '//skillet.lifehacker.com',
#  '//twocents.lifehacker.com',
#  '//vitals.lifehacker.com',
#  '//offspring.lifehacker.com',
#  '//lifehacker.com/c/the-upgrade',
#  '//lifehacker.com/c/app-directory',
#  '//lifehacker.com/c/how-i-work',
#  '//lifehacker.com',
#  '//lifehacker.com/video',
#  '//skillet.lifehacker.com',
#  '//twocents.lifehacker.com',
#  '//vitals.lifehacker.com',
#  '//offspring.lifehacker.com',
#  '//lifehacker.com/c/the-upgrade',
#  '//lifehacker.com/c/app-directory',
#  '//lifehacker.com/c/how-i-work',
#  'https://lifehacker.com/whats-making-you-crazy-at-work-1832475937',
#  'https://lifehacker.com/c/human-resource',
#  'https://lifehacker.com/whats-making-you-crazy-at-work-1832475937',
#  'https://kinja.com/humanresource',
#  'https://offspring.lifehacker.com/how-to-help-your-teen-through-their-first-break-up-1832566503',
#  'https://offspring.lifehacker.com/how-to-help-your-teen-through-their-first-break-up-1832566503',
#  'https://kinja.com/megwalbert',
#  'https://vitals.lifehacker.com/we-reject-all-water-drinking-hacks-1832586287',
#  'https://vitals.lifehacker.com/we-reject-all-water-drinking-hacks-1832586287',
#  'https://kinja.com/bethskw',
#  'https://skillet.lifehacker.com/make-papa-johns-garlic-butter-sauce-with-no-garlic-and-1832562305',
#  'https://skillet.lifehacker.com/make-papa-johns-garlic-butter-sauce-with-no-garlic-and-1832562305',
#  'https://kinja.com/joelkahn',
#  'https://points.theinventory.com/one-of-our-favorite-travel-rewards-cards-has-a-new-name-1832567154',
#  '//kinja.com/shepmcallister',
#  'https://points.theinventory.com/one-of-our-favorite-travel-rewards-cards-has-a-new-name-1832567154',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://points.theinventory.com/one-of-our-favorite-travel-rewards-cards-has-a-new-name-1832567154',
#  '#',
#  'https://points.theinventory.com/one-of-our-favorite-travel-rewards-cards-has-a-new-name-1832567154',
#  'https://points.theinventory.com/the-spg-luxury-card-may-be-the-king-of-hotel-cards-at-1828695917?ks=nativestream',
#  'https://thepointsguy.com/card-details/marriott-bonvoy-brilliant-american-express-card/?utm_campaign=lifehacker_ultimaterewardsguide&utm_source=referral',
#  'https://kinjadeals.theinventory.com/you-dont-need-any-leverage-to-get-this-torque-wrench-fo-1832599076',
#  'https://kinjadeals.theinventory.com/you-dont-need-any-leverage-to-get-this-torque-wrench-fo-1832599076',
#  'https://kinjadeals.theinventory.com/you-dont-need-any-leverage-to-get-this-torque-wrench-fo-1832599076#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://kinjadeals.theinventory.com/you-dont-need-any-leverage-to-get-this-torque-wrench-fo-1832599076',
#  '#',
#  'https://kinjadeals.theinventory.com/you-dont-need-any-leverage-to-get-this-torque-wrench-fo-1832599076',
#  'https://www.amazon.com/dp/B07FF1YL4K/?m=A2W3XL8X3JZP21&tag=kinjadeals-20&ascsubtag=cc419f71fc11b88ebfaa3d64d03e7028e4221ae6',
#  '',
#  '#',
#  '#',
#  'https://lifehacker.com/c/rejection-week',
#  'https://vitals.lifehacker.com/its-ok-to-fail-at-the-gym-1832593004',
#  '//kinja.com/joshocampo',
#  'https://vitals.lifehacker.com/its-ok-to-fail-at-the-gym-1832593004',
#  'https://vitals.lifehacker.com/its-ok-to-fail-at-the-gym-1832593004#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://vitals.lifehacker.com/its-ok-to-fail-at-the-gym-1832593004',
#  '#',
#  'https://vitals.lifehacker.com/its-ok-to-fail-at-the-gym-1832593004',
#  'https://lifehacker.com/c/rejection-week',
#  'https://lifehacker.com/we-reject-the-side-hustle-1832566443',
#  '//kinja.com/vksmith',
#  'https://lifehacker.com/we-reject-the-side-hustle-1832566443',
#  'https://lifehacker.com/we-reject-the-side-hustle-1832566443#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://lifehacker.com/we-reject-the-side-hustle-1832566443',
#  '#',
#  'https://lifehacker.com/we-reject-the-side-hustle-1832566443',
#  'https://twocents.lifehacker.com/the-worst-stuff-written-about-money-in-2018-1831360785',
#  'https://lifehacker.com/c/rejection-week',
#  'https://lifehacker.com/how-successful-people-deal-with-rejection-at-work-1832559866',
#  '//kinja.com/nickdouglas',
#  'https://lifehacker.com/how-successful-people-deal-with-rejection-at-work-1832559866',
#  'https://lifehacker.com/how-successful-people-deal-with-rejection-at-work-1832559866#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://lifehacker.com/how-successful-people-deal-with-rejection-at-work-1832559866',
#  '#',
#  'https://lifehacker.com/how-successful-people-deal-with-rejection-at-work-1832559866',
#  'https://lifehacker.com/c/how-i-work',
#  '',
#  '#',
#  '#',
#  'https://news.theinventory.com/you-probably-dont-need-a-tool-free-nvme-ssd-enclosure-1832596637',
#  '//kinja.com/shepmcallister',
#  'https://news.theinventory.com/you-probably-dont-need-a-tool-free-nvme-ssd-enclosure-1832596637',
#  'https://news.theinventory.com/you-probably-dont-need-a-tool-free-nvme-ssd-enclosure-1832596637#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://news.theinventory.com/you-probably-dont-need-a-tool-free-nvme-ssd-enclosure-1832596637',
#  '#',
#  'https://news.theinventory.com/you-probably-dont-need-a-tool-free-nvme-ssd-enclosure-1832596637',
#  'https://www.amazon.com/dp/B07M7Q21N7?tag=theinventory-20&ascsubtag=ae5826979e34d96d364dcae3a5daa003fde041a3',
#  'https://theinventory.com/build-your-own-external-ssd-for-cheaper-faster-storage-1763354004',
#  'https://thetakeout.com/recipe-honey-garlic-crispy-beef-chinese-takeout-1832566789',
#  '//kinja.com/kevinpang',
#  'https://thetakeout.com/recipe-honey-garlic-crispy-beef-chinese-takeout-1832566789',
#  'https://thetakeout.com/recipe-honey-garlic-crispy-beef-chinese-takeout-1832566789#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://thetakeout.com/recipe-honey-garlic-crispy-beef-chinese-takeout-1832566789',
#  '#',
#  'https://thetakeout.com/recipe-honey-garlic-crispy-beef-chinese-takeout-1832566789',
#  'https://thetakeout.com/tag/garlic-week',
#  'https://lifehacker.com/where-to-vacation-on-valentines-day-if-youre-single-1832588301',
#  '//kinja.com/alutkin',
#  'https://lifehacker.com/where-to-vacation-on-valentines-day-if-youre-single-1832588301',
#  'https://lifehacker.com/where-to-vacation-on-valentines-day-if-youre-single-1832588301#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://lifehacker.com/where-to-vacation-on-valentines-day-if-youre-single-1832588301',
#  '#',
#  'https://lifehacker.com/where-to-vacation-on-valentines-day-if-youre-single-1832588301',
#  'https://lifehacker.com/c/veggie-heavy',
#  'https://skillet.lifehacker.com/soak-your-beans-in-the-fridge-for-faster-meal-prep-1832374408',
#  '//kinja.com/aanewton',
#  'https://skillet.lifehacker.com/soak-your-beans-in-the-fridge-for-faster-meal-prep-1832374408',
#  'https://skillet.lifehacker.com/soak-your-beans-in-the-fridge-for-faster-meal-prep-1832374408#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://skillet.lifehacker.com/soak-your-beans-in-the-fridge-for-faster-meal-prep-1832374408',
#  '#',
#  'https://skillet.lifehacker.com/soak-your-beans-in-the-fridge-for-faster-meal-prep-1832374408',
#  'https://skillet.lifehacker.com/you-dont-have-to-soak-dried-beans-overnight-1818565255',
#  'https://kinjadeals.theinventory.com/scatter-these-anker-qi-pads-around-your-house-for-12-e-1832488013',
#  'https://kinjadeals.theinventory.com/scatter-these-anker-qi-pads-around-your-house-for-12-e-1832488013',
#  'https://kinjadeals.theinventory.com/scatter-these-anker-qi-pads-around-your-house-for-12-e-1832488013#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://kinjadeals.theinventory.com/scatter-these-anker-qi-pads-around-your-house-for-12-e-1832488013',
#  '#',
#  'https://kinjadeals.theinventory.com/scatter-these-anker-qi-pads-around-your-house-for-12-e-1832488013',
#  'https://lifehacker.com/stop-using-so-much-salt-on-sidewalks-1832588841',
#  '//kinja.com/joshocampo',
#  'https://lifehacker.com/stop-using-so-much-salt-on-sidewalks-1832588841',
#  'https://lifehacker.com/stop-using-so-much-salt-on-sidewalks-1832588841#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://lifehacker.com/stop-using-so-much-salt-on-sidewalks-1832588841',
#  '#',
#  'https://lifehacker.com/stop-using-so-much-salt-on-sidewalks-1832588841',
#  'https://jalopnik.com/the-used-cars-that-will-save-you-the-most-over-new-cars-1832587817',
#  '//kinja.com/tommcparland',
#  'https://jalopnik.com/the-used-cars-that-will-save-you-the-most-over-new-cars-1832587817',
#  'https://jalopnik.com/the-used-cars-that-will-save-you-the-most-over-new-cars-1832587817#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://jalopnik.com/the-used-cars-that-will-save-you-the-most-over-new-cars-1832587817',
#  '#',
#  'https://jalopnik.com/the-used-cars-that-will-save-you-the-most-over-new-cars-1832587817',
#  'https://www.iseecars.com/cars-to-buy-used-2019-study',
#  'https://lifehacker.com/c/human-resource',
#  'https://lifehacker.com/how-to-get-fired-1832440163',
#  '//kinja.com/humanresource',
#  'https://lifehacker.com/how-to-get-fired-1832440163',
#  'https://lifehacker.com/how-to-get-fired-1832440163#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://lifehacker.com/how-to-get-fired-1832440163',
#  '#',
#  'https://lifehacker.com/how-to-get-fired-1832440163',
#  'https://kinjadeals.theinventory.com/it-aint-hard-to-tell-this-is-the-right-time-to-buy-a-n-1832591230',
#  'https://kinjadeals.theinventory.com/it-aint-hard-to-tell-this-is-the-right-time-to-buy-a-n-1832591230',
#  'https://kinjadeals.theinventory.com/it-aint-hard-to-tell-this-is-the-right-time-to-buy-a-n-1832591230#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://kinjadeals.theinventory.com/it-aint-hard-to-tell-this-is-the-right-time-to-buy-a-n-1832591230',
#  '#',
#  'https://kinjadeals.theinventory.com/it-aint-hard-to-tell-this-is-the-right-time-to-buy-a-n-1832591230',
#  'http://www.anrdoezrs.net/links/8335291/type/dlg/https://computers.woot.com/offers/qnap-ts-328-personal-cloud-nas-storage-system-13',
#  'https://lifehacker.com/c/video',
#  'https://skillet.lifehacker.com/make-papa-johns-garlic-butter-sauce-with-no-garlic-and-1832562305',
#  '//kinja.com/joelkahn',
#  'https://skillet.lifehacker.com/make-papa-johns-garlic-butter-sauce-with-no-garlic-and-1832562305',
#  'https://skillet.lifehacker.com/make-papa-johns-garlic-butter-sauce-with-no-garlic-and-1832562305#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://skillet.lifehacker.com/make-papa-johns-garlic-butter-sauce-with-no-garlic-and-1832562305',
#  '#',
#  'https://vitals.lifehacker.com/himalayan-salt-is-just-salt-but-pink-1832591496',
#  '//kinja.com/bethskw',
#  'https://vitals.lifehacker.com/himalayan-salt-is-just-salt-but-pink-1832591496',
#  'https://vitals.lifehacker.com/himalayan-salt-is-just-salt-but-pink-1832591496#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://vitals.lifehacker.com/himalayan-salt-is-just-salt-but-pink-1832591496',
#  '#',
#  'https://vitals.lifehacker.com/himalayan-salt-is-just-salt-but-pink-1832591496',
#  'https://lifehacker.com/c/rejection-week',
#  'https://lifehacker.com/what-to-do-if-youre-rejected-on-social-media-1832560593',
#  '//kinja.com/thedavidmurphy',
#  'https://lifehacker.com/what-to-do-if-youre-rejected-on-social-media-1832560593',
#  'https://lifehacker.com/what-to-do-if-youre-rejected-on-social-media-1832560593#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://lifehacker.com/what-to-do-if-youre-rejected-on-social-media-1832560593',
#  '#',
#  'https://lifehacker.com/what-to-do-if-youre-rejected-on-social-media-1832560593',
#  'https://lifehacker.com/konmari-your-twitter-feed-with-this-tool-1832407341',
#  'https://lifehacker.com/how-to-reject-someone-on-social-media-1832464867',
#  'https://lifehacker.com/c/rejection-week',
#  'https://vitals.lifehacker.com/we-reject-all-water-drinking-hacks-1832586287',
#  '//kinja.com/bethskw',
#  'https://vitals.lifehacker.com/we-reject-all-water-drinking-hacks-1832586287',
#  'https://vitals.lifehacker.com/we-reject-all-water-drinking-hacks-1832586287#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://vitals.lifehacker.com/we-reject-all-water-drinking-hacks-1832586287',
#  '#',
#  'https://vitals.lifehacker.com/we-reject-all-water-drinking-hacks-1832586287',
#  'https://kinjadeals.theinventory.com/wednesdays-best-deals-hot-honey-baby-clothes-macbook-1832588849',
#  'https://kinjadeals.theinventory.com/wednesdays-best-deals-hot-honey-baby-clothes-macbook-1832588849',
#  'https://kinjadeals.theinventory.com/wednesdays-best-deals-hot-honey-baby-clothes-macbook-1832588849#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://kinjadeals.theinventory.com/wednesdays-best-deals-hot-honey-baby-clothes-macbook-1832588849',
#  '#',
#  'https://kinjadeals.theinventory.com/wednesdays-best-deals-hot-honey-baby-clothes-macbook-1832588849',
#  'https://kinjadeals.theinventory.com/our-readers-can-take-50-off-status-audios-cult-favorit-1832586801?rev=1550065135737',
#  'https://kinjadeals.theinventory.com/this-13-anker-car-charger-is-also-a-bluetooth-fm-trans-1829105068?rev=1550063376192',
#  'https://lifehacker.com/download-the-national-parks-typeface-for-free-1832359415',
#  '//kinja.com/emilyannlong',
#  'https://lifehacker.com/download-the-national-parks-typeface-for-free-1832359415',
#  'https://lifehacker.com/download-the-national-parks-typeface-for-free-1832359415#replies',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'https://lifehacker.com/download-the-national-parks-typeface-for-free-1832359415',
#  '#',
#  'https://lifehacker.com/download-the-national-parks-typeface-for-free-1832359415',
#  '?startTime=1550071800414',
#  'https://kotaku.com/zelda-links-awakening-is-getting-remastered-for-switch-1832604452',
#  'https://io9.gizmodo.com/neither-kevin-feige-or-brie-larson-wanted-ms-marvels-b-1832589656',
#  'https://kotaku.com/the-fallout-of-activision-blizzard-s-massive-layoffs-1832597892',
#  'https://kotaku.com/zelda-links-awakening-is-getting-remastered-for-switch-1832604452',
#  'https://io9.gizmodo.com/neither-kevin-feige-or-brie-larson-wanted-ms-marvels-b-1832589656',
#  'https://kotaku.com/the-fallout-of-activision-blizzard-s-massive-layoffs-1832597892',
#  'https://vitals.lifehacker.com/himalayan-salt-is-just-salt-but-pink-1832591496',
#  'https://lifehacker.com/try-reddits-best-tips-for-reading-more-books-1832394982',
#  'https://lifehacker.com/we-reject-the-side-hustle-1832566443']
